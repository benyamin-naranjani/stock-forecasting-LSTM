# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from datetime import datetime
# Out:
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
import yfinance as yf
import pandas as pd
import time

# ============================================
# 1. ORIGINAL TICKERS (YOUR DOWNLOADED LIST)
# ============================================

tickers = [
"MMM","AOS","ABT","ABBV","ACN","ADBE","AMD","AES","AFL","A","AAP","AMT","AWK",
"AMP","ABC","AME","AMGN","APH","ADI","ANSS","ANTM","AON","APA","AAPL","AMAT",
"APTV","ADM","ANET","AJG","AIZ","T","ATO","ADSK","AZO","AVB","AVY","BKR","BLL",
"BAC","BK","BAX","BDX","BRO","BBWI","BR","BMY","AVGO","BRK-B","CDNS","CZR",
"CPB","COF","CAH","KMX","CCL","CARR","CTLT","CAT","CBOE","CBRE","CDW","CE","CNC",
"CNP","CDAY","CF","CRL","SCHW","CHTR","CVX","CMG","CB","CHD","CI","CINF","CTAS",
"CSCO","C","CFG","CTXS","CLX","CME","CMS","KO","CTSH","CL","CMCSA","CMA","CAG",
"COP","ED","STZ","CEG","COO","CPRT","GLW","CTVA","CSX","CMI","CVS","DHI","DHR",
"DRI","DVA","DE","DAL","XRAY","DVN","DXCM","FANG","DLR","DFS","DIS","DG","DLTR",
"D","DPZ","DOV","DOW","DTE","DUK","DRE","DD","DXC","EMN","ETN","EBAY","ECL",
"EIX","EW","EA","EMR","ENPH","ETR","EOG","EFX","EQIX","EQR","ESS","EL","ETSY",
"RE","EXC","EXPE","EXPD","EXR","XOM","FFIV","FDS","FIS","FITB","FE","FRC","FISV",
"FLT","FMC","F","FTNT","FTV","FBHS","FOXA","FOX","BEN","FCX","GRMN","IT","GNRC",
"GD","GE","GIS","GM","GPC","GILD","GPN","GL","GS","HAL","HIG","HAS","HCA","PEAK",
"HSIC","HSY","HES","HPE","HLT","HOLX","HD","HON","HRL","HST","HWM","HPQ","HUM",
"HBAN","HII","IBM","IEX","IDXX","ITW","ILMN","INCY","IR","INTC","ICE","IFF","IP",
"IPG","INTU","ISRG","IVZ","IPGP","IQV","IRM","JBHT","J","SJM","JNJ","JCI","JPM",
"JNPR","K","KEY","KEYS","KMB","KIM","KMI","KLAC","KHC","KR","LHX","LH","LRCX",
"LW","LVS","LDOS","LEN","LLY","LNC","LIN","LYV","LKQ","LMT","L","LOW","LUMN",
"LYB","MTB","MRO","MPC","MKTX","MAR","MMC","MLM","MAS","MA","MTCH","MKC","MCD",
"MCK","MDT","MRK","META","MTD","MGM","MCHP","MU","MSFT","MAA","MRNA","MHK","TAP",
"MDLZ","MPWR","MNST","MCO","MS","MOS","MSI","MSCI","NDAQ","NTAP","NFLX","NWL",
"NEM","NWSA","NWS","NEE","NLSN","NKE","NI","NSC","NTRS","NOC","NLOK","NVR","NXPI",
"ORLY","OXY","ODFL","OMC","OKE","ORCL","OGN","OTIS","PCAR","PKG","PH","PAYX",
"PAYC","PFE","PM","PSX","PNW","PXD","PNC","POOL","PPG","PPL","PFG","PG","PGR",
"PLD","PRU","PEG","PSA","PHM","PVH","QRVO","QCOM","DGX","RL","ROP","ROST","RCL",
"SPGI","CRM","SBAC","SLB","STX","SEE","SRE","SHW","SPG","SWKS","SNA","SO","LUV",
"SWK","SBUX","STT","STE","SYK","SIVB","SYF","SNPS","SYY","TMUS","TROW","TT","TDY",
"TFX","TER","TSLA","TXN","TXT","TMO","TJX","TSCO","TTWO","TDG","TRV","TRMB",
"TFC","TWTR","TYL","TSN","UDR","ULTA","USB","UAA","UA","UNP","UAL","UPS","URI",
"UNH","UHS","VFC","VTR","VTRS","VICI","VZ","V","VMW","VNO","VMC","WRB","WAB",
"WMT","WBA","DIS","WM","WAT","WEC","WFC","WELL","WDC","WHR","WMB","WLTW","WYNN",
"XEL","XLNX","XYL","YUM","ZBRA","ZBH","ZION","ZTS"
]


# ============================================
# 2. FIX MAP (RENAME BROKEN TICKERS)
# ============================================

ticker_fix = {
    "ABC": "COR",     # AmerisourceBergen → Cencora
    "ANTM": "ELV",    # Anthem → Elevance Health
    "BLL": "BALL",    # Ball Corp
    "CDAY": "DAY",    # Ceridian → Dayforce
    "FLT": "CORP",    # renamed to CORP
    "FBHS": "FBIN",   # Fortune Brands
    "PEAK": "DOC",    # merged → Physicians Realty
    "RE": "EG",       # renamed
    "NLOK": "GEN",    # Norton → Gen Digital
    "WLTW": "WTW",    # Willis Towers Watson → WTW
}

# ============================================
# 3. REMOVE LIST (DELISTED / MERGED / DEAD)
# ============================================

remove_list = [
    "ANSS","CTLT","CTXS","DFS","DRE","FRC","HES","JNPR","MRO",
    "NLSN","PXD","SIVB","TWTR","VMW","WBA","XLNX"
]


# ============================================
# 4. CLEAN FINAL TICKER LIST
# ============================================

cleaned_tickers = []
for t in tickers:
    if t in remove_list:
        continue
    cleaned_tickers.append(ticker_fix.get(t, t))

len(cleaned_tickers)
# Out:
# 404

# %%
all_data = {}
start_date = "2000-01-01"
failed = []

for t in cleaned_tickers:
    try:
        print("Downloading:", t)
        df = yf.download(t, start=start_date, auto_adjust=True, progress=False)

        # require enough history
        if df.shape[0] < 4000:
            raise Exception("Insufficient history")

        all_data[t] = df["Close"]
    except Exception as e:
        print("FAILED:", t, e)
        failed.append(t)
    
    time.sleep(0.10)  # avoid rate limit

print("\nSuccess:", len(all_data), "stocks")
print("Failed:", len(failed), failed)
# Out:
# Downloading: MMM
# Downloading: AOS
# Downloading: ABT
# Downloading: ABBV
# FAILED: ABBV Insufficient history
# Downloading: ACN
# Downloading: ADBE
# Downloading: AMD
# Downloading: AES
# Downloading: AFL
# Downloading: A
# Downloading: AAP
# Downloading: AMT
# Downloading: AWK
# Downloading: AMP
# Downloading: COR
# Downloading: AME
# Downloading: AMGN
# Downloading: APH
# Downloading: ADI
# Downloading: ELV
# Downloading: AON
# Downloading: APA
# Downloading: AAPL
# Downloading: AMAT
# Downloading: APTV
# FAILED: APTV Insufficient history
# Downloading: ADM
# Downloading: ANET
# FAILED: ANET Insufficient history
# Downloading: AJG
# Downloading: AIZ
# Downloading: T
# Downloading: ATO
# Downloading: ADSK
# Downloading: AZO
# Downloading: AVB
# Downloading: AVY
# Downloading: BKR
# Downloading: BALL
# Downloading: BAC
# Downloading: BK
# Downloading: BAX
# Downloading: BDX
# Downloading: BRO
# Downloading: BBWI
# Downloading: BR
# Downloading: BMY
# Downloading: AVGO
# Downloading: BRK-B
# Downloading: CDNS
# Downloading: CZR
# FAILED: CZR Insufficient history
# Downloading: CPB
# Downloading: COF
# Downloading: CAH
# Downloading: KMX
# Downloading: CCL
# Downloading: CARR
# FAILED: CARR Insufficient history
# Downloading: CAT
# Downloading: CBOE
# FAILED: CBOE Insufficient history
# Downloading: CBRE
# Downloading: CDW
# FAILED: CDW Insufficient history
# Downloading: CE
# Downloading: CNC
# Downloading: CNP
# Downloading: DAY
# FAILED: DAY Insufficient history
# Downloading: CF
# Downloading: CRL
# Downloading: SCHW
# Downloading: CHTR
# FAILED: CHTR Insufficient history
# Downloading: CVX
# Downloading: CMG
# Downloading: CB
# Downloading: CHD
# Downloading: CI
# Downloading: CINF
# Downloading: CTAS
# Downloading: CSCO
# Downloading: C
# Downloading: CFG
# FAILED: CFG Insufficient history
# Downloading: CLX
# Downloading: CME
# Downloading: CMS
# Downloading: KO
# Downloading: CTSH
# Downloading: CL
# Downloading: CMCSA
# Downloading: CMA
# Downloading: CAG
# Downloading: COP
# Downloading: ED
# Downloading: STZ
# Downloading: CEG
# FAILED: CEG Insufficient history
# Downloading: COO
# Downloading: CPRT
# Downloading: GLW
# Downloading: CTVA
# FAILED: CTVA Insufficient history
# Downloading: CSX
# Downloading: CMI
# Downloading: CVS
# Downloading: DHI
# Downloading: DHR
# Downloading: DRI
# Downloading: DVA
# Downloading: DE
# Downloading: DAL
# Downloading: XRAY
# Downloading: DVN
# Downloading: DXCM
# Downloading: FANG
# FAILED: FANG Insufficient history
# Downloading: DLR
# Downloading: DIS
# Downloading: DG
# Downloading: DLTR
# Downloading: D
# Downloading: DPZ
# Downloading: DOV
# Downloading: DOW
# FAILED: DOW Insufficient history
# Downloading: DTE
# Downloading: DUK
# Downloading: DD
# Downloading: DXC
# Downloading: EMN
# Downloading: ETN
# Downloading: EBAY
# Downloading: ECL
# Downloading: EIX
# Downloading: EW
# Downloading: EA
# Downloading: EMR
# Downloading: ENPH
# FAILED: ENPH Insufficient history
# Downloading: ETR
# Downloading: EOG
# Downloading: EFX
# Downloading: EQIX
# Downloading: EQR
# Downloading: ESS
# Downloading: EL
# Downloading: ETSY
# FAILED: ETSY Insufficient history
# Downloading: EG
# Downloading: EXC
# Downloading: EXPE
# Downloading: EXPD
# Downloading: EXR
# Downloading: XOM
# Downloading: FFIV
# Downloading: FDS
# Downloading: FIS
# Downloading: FITB
# Downloading: FE
# Downloading: FISV
# Downloading: CORP
# FAILED: CORP Insufficient history
# Downloading: FMC
# Downloading: F
# Downloading: FTNT
# Downloading: FTV
# FAILED: FTV Insufficient history
# Downloading: FBIN
# FAILED: FBIN Insufficient history
# Downloading: FOXA
# FAILED: FOXA Insufficient history
# Downloading: FOX
# FAILED: FOX Insufficient history
# Downloading: BEN
# Downloading: FCX
# Downloading: GRMN
# Downloading: IT
# Downloading: GNRC
# FAILED: GNRC Insufficient history
# Downloading: GD
# Downloading: GE
# Downloading: GIS
# Downloading: GM
# FAILED: GM Insufficient history
# Downloading: GPC
# Downloading: GILD
# Downloading: GPN
# Downloading: GL
# Downloading: GS
# Downloading: HAL
# Downloading: HIG
# Downloading: HAS
# Downloading: HCA
# FAILED: HCA Insufficient history
# Downloading: DOC
# Downloading: HSIC
# Downloading: HSY
# Downloading: HPE
# FAILED: HPE Insufficient history
# Downloading: HLT
# FAILED: HLT Insufficient history
# Downloading: HOLX
# Downloading: HD
# Downloading: HON
# Downloading: HRL
# Downloading: HST
# Downloading: HWM
# FAILED: HWM Insufficient history
# Downloading: HPQ
# Downloading: HUM
# Downloading: HBAN
# Downloading: HII
# FAILED: HII Insufficient history
# Downloading: IBM
# Downloading: IEX
# Downloading: IDXX
# Downloading: ITW
# Downloading: ILMN
# Downloading: INCY
# Downloading: IR
# FAILED: IR Insufficient history
# Downloading: INTC
# Downloading: ICE
# Downloading: IFF
# Downloading: IP
# Downloading: IPG
# Downloading: INTU
# Downloading: ISRG
# Downloading: IVZ
# Downloading: IPGP
# Downloading: IQV
# FAILED: IQV Insufficient history
# Downloading: IRM
# Downloading: JBHT
# Downloading: J
# Downloading: SJM
# Downloading: JNJ
# Downloading: JCI
# Downloading: JPM
# Downloading: K
# Downloading: KEY
# Downloading: KEYS
# FAILED: KEYS Insufficient history
# Downloading: KMB
# Downloading: KIM
# Downloading: KMI
# FAILED: KMI Insufficient history
# Downloading: KLAC
# Downloading: KHC
# FAILED: KHC Insufficient history
# Downloading: KR
# Downloading: LHX
# Downloading: LH
# Downloading: LRCX
# Downloading: LW
# FAILED: LW Insufficient history
# Downloading: LVS
# Downloading: LDOS
# Downloading: LEN
# Downloading: LLY
# Downloading: LNC
# Downloading: LIN
# Downloading: LYV
# Downloading: LKQ
# Downloading: LMT
# Downloading: L
# Downloading: LOW
# Downloading: LUMN
# Downloading: LYB
# FAILED: LYB Insufficient history
# Downloading: MTB
# Downloading: MPC
# FAILED: MPC Insufficient history
# Downloading: MKTX
# Downloading: MAR
# Downloading: MMC
# Downloading: MLM
# Downloading: MAS
# Downloading: MA
# Downloading: MTCH
# Downloading: MKC
# Downloading: MCD
# Downloading: MCK
# Downloading: MDT
# Downloading: MRK
# Downloading: META
# FAILED: META Insufficient history
# Downloading: MTD
# Downloading: MGM
# Downloading: MCHP
# Downloading: MU
# Downloading: MSFT
# Downloading: MAA
# Downloading: MRNA
# FAILED: MRNA Insufficient history
# Downloading: MHK
# Downloading: TAP
# Downloading: MDLZ
# Downloading: MPWR
# Downloading: MNST
# Downloading: MCO
# Downloading: MS
# Downloading: MOS
# Downloading: MSI
# Downloading: MSCI
# Downloading: NDAQ
# Downloading: NTAP
# Downloading: NFLX
# Downloading: NWL
# Downloading: NEM
# Downloading: NWSA
# FAILED: NWSA Insufficient history
# Downloading: NWS
# FAILED: NWS Insufficient history
# Downloading: NEE
# Downloading: NKE
# Downloading: NI
# Downloading: NSC
# Downloading: NTRS
# Downloading: NOC
# Downloading: GEN
# Downloading: NVR
# Downloading: NXPI
# FAILED: NXPI Insufficient history
# Downloading: ORLY
# Downloading: OXY
# Downloading: ODFL
# Downloading: OMC
# Downloading: OKE
# Downloading: ORCL
# Downloading: OGN
# FAILED: OGN Insufficient history
# Downloading: OTIS
# FAILED: OTIS Insufficient history
# Downloading: PCAR
# Downloading: PKG
# Downloading: PH
# Downloading: PAYX
# Downloading: PAYC
# FAILED: PAYC Insufficient history
# Downloading: PFE
# Downloading: PM
# Downloading: PSX
# FAILED: PSX Insufficient history
# Downloading: PNW
# Downloading: PNC
# Downloading: POOL
# Downloading: PPG
# Downloading: PPL
# Downloading: PFG
# Downloading: PG
# Downloading: PGR
# Downloading: PLD
# Downloading: PRU
# Downloading: PEG
# Downloading: PSA
# Downloading: PHM
# Downloading: PVH
# Downloading: QRVO
# FAILED: QRVO Insufficient history
# Downloading: QCOM
# Downloading: DGX
# Downloading: RL
# Downloading: ROP
# Downloading: ROST
# Downloading: RCL
# Downloading: SPGI
# Downloading: CRM
# Downloading: SBAC
# Downloading: SLB
# Downloading: STX
# Downloading: SEE
# Downloading: SRE
# Downloading: SHW
# Downloading: SPG
# Downloading: SWKS
# Downloading: SNA
# Downloading: SO
# Downloading: LUV
# Downloading: SWK
# Downloading: SBUX
# Downloading: STT
# Downloading: STE
# Downloading: SYK
# Downloading: SYF
# FAILED: SYF Insufficient history
# Downloading: SNPS
# Downloading: SYY
# Downloading: TMUS
# Downloading: TROW
# Downloading: TT
# Downloading: TDY
# Downloading: TFX
# Downloading: TER
# Downloading: TSLA
# FAILED: TSLA Insufficient history
# Downloading: TXN
# Downloading: TXT
# Downloading: TMO
# Downloading: TJX
# Downloading: TSCO
# Downloading: TTWO
# Downloading: TDG
# Downloading: TRV
# Downloading: TRMB
# Downloading: TFC
# Downloading: TYL
# Downloading: TSN
# Downloading: UDR
# Downloading: ULTA
# Downloading: USB
# Downloading: UAA
# Downloading: UA
# FAILED: UA Insufficient history
# Downloading: UNP
# Downloading: UAL
# Downloading: UPS
# Downloading: URI
# Downloading: UNH
# Downloading: UHS
# Downloading: VFC
# Downloading: VTR
# Downloading: VTRS
# Downloading: VICI
# FAILED: VICI Insufficient history
# Downloading: VZ
# Downloading: V
# Downloading: VNO
# Downloading: VMC
# Downloading: WRB
# Downloading: WAB
# Downloading: WMT
# Downloading: DIS
# Downloading: WM
# Downloading: WAT
# Downloading: WEC
# Downloading: WFC
# Downloading: WELL
# Downloading: WDC
# Downloading: WHR
# Downloading: WMB
# Downloading: WTW
# Downloading: WYNN
# Downloading: XEL
# Downloading: XYL
# FAILED: XYL Insufficient history
# Downloading: YUM
# Downloading: ZBRA
# Downloading: ZBH
# Downloading: ZION
# Downloading: ZTS
# FAILED: ZTS Insufficient history
#
# Success: 351 stocks
# Failed: 52 ['ABBV', 'APTV', 'ANET', 'CZR', 'CARR', 'CBOE', 'CDW', 'DAY', 'CHTR', 'CFG', 'CEG', 'CTVA', 'FANG', 'DOW', 'ENPH', 'ETSY', 'CORP', 'FTV', 'FBIN', 'FOXA', 'FOX', 'GNRC', 'GM', 'HCA', 'HPE', 'HLT', 'HWM', 'HII', 'IR', 'IQV', 'KEYS', 'KMI', 'KHC', 'LW', 'LYB', 'MPC', 'META', 'MRNA', 'NWSA', 'NWS', 'NXPI', 'OGN', 'OTIS', 'PAYC', 'PSX', 'QRVO', 'SYF', 'TSLA', 'UA', 'VICI', 'XYL', 'ZTS']

# %%
import numpy as np
import pandas as pd

# ============================================================
# CONFIG
# ============================================================
WINDOW  = 60
HORIZON = 60
EPS     = 1e-8

tickers = list(all_data.keys())
ticker_to_id = {t: i for i, t in enumerate(tickers)}


# ============================================================
# UNIVERSAL PRICE EXTRACTOR
# ============================================================
def extract_price(df, ticker):

    if isinstance(df.columns, pd.MultiIndex):
        level0 = df.columns.get_level_values(0)

        if "Close" in level0:
            close_cols = [c for c in df.columns if c[0] == "Close"]

            if len(close_cols) == 1:
                price = df[close_cols[0]]
            else:
                match = [c for c in close_cols if c[1] == ticker]
                if len(match) == 1:
                    price = df[match[0]]
                else:
                    price = df[close_cols[0]]
        else:
            price = df.iloc[:, 0]

    else:
        if "Close" in df.columns:
            price = df["Close"]
        elif "Adj Close" in df.columns:
            price = df["Adj Close"]
        else:
            price = df.iloc[:, 0]

    return price.rename("price").dropna()


# ============================================================
# STEP 1 — BUILD RAW X, raw y, stock_ids, dates  (FINAL FIXED)
# ============================================================
X_list      = []
y_list      = []
ids_list    = []
dates_list  = []

for t in tickers:

    price = extract_price(all_data[t], t)
    prices = price.values
    dates  = price.index

    # FIXED: correct number of valid windows
    max_i = len(prices) - (WINDOW + HORIZON + 1)
    if max_i < 0:
        continue

    for i in range(max_i + 1):

        window = prices[i : i + WINDOW]

        current_price = prices[i + WINDOW - 1]
        future_price  = prices[i + WINDOW + HORIZON]  # <-- now ALWAYS valid

        future_return = (future_price - current_price) / (current_price + EPS)

        X_list.append(window)
        y_list.append(future_return)
        ids_list.append(ticker_to_id[t])
        dates_list.append(dates[i + WINDOW])



# Convert to arrays (all perfectly aligned)
X         = np.array(X_list)
y         = np.array(y_list)
stock_ids = np.array(ids_list)
dates_arr = np.array(dates_list)

print("X:",      X.shape)
print("y:",      y.shape)
print("stock_ids:", stock_ids.shape)
print("dates:",  len(dates_arr))


# ============================================================
# STEP 2 — CONVERT y → CONTINUOUS DAILY RANK (0–1)
# ============================================================

df_tmp = pd.DataFrame({
    "date": dates_arr,
    "y":    y
})

# Rank within each date only (safe)
df_tmp["rank"] = df_tmp.groupby("date")["y"].rank(method="dense", pct=True)

y_rank = df_tmp["rank"].values.astype(np.float32)

print("\nRanked y distribution:")
print(pd.Series(y_rank).describe())


# ============================================================
# STEP 3 — TRAIN / VAL / TEST SPLIT
# ============================================================

dates_pd = pd.to_datetime(dates_arr)

train_mask = dates_pd <  pd.Timestamp("2020-01-01")

# Validation extended by 1 year → 2016–2020
val_mask   = (dates_pd >= pd.Timestamp("2020-01-01")) & (dates_pd < pd.Timestamp("2024-01-01"))

# Test now begins 2020+
test_mask  = dates_pd >= pd.Timestamp("2024-01-01")

# X splits
X_train = X[train_mask]
X_val   = X[val_mask]
X_test  = X[test_mask]

# y_rank splits
y_train = y_rank[train_mask]
y_val   = y_rank[val_mask]
y_test  = y_rank[test_mask]

# IDs & dates
ids_train  = stock_ids[train_mask]
ids_val    = stock_ids[val_mask]
ids_test   = stock_ids[test_mask]

dates_train = dates_pd[train_mask]
dates_val   = dates_pd[val_mask]
dates_test  = dates_pd[test_mask]

print("\nTrain:", X_train.shape)
print("Val:  ",  X_val.shape)
print("Test: ",  X_test.shape)


# ============================================================
# STEP 4 — NORMALIZATION PER WINDOW
# ============================================================
def normalize_window(w):
    mu = w.mean()
    sd = w.std() + 1e-6
    return (w - mu) / sd

X_train = np.array([normalize_window(w) for w in X_train])
X_val   = np.array([normalize_window(w) for w in X_val])
X_test  = np.array([normalize_window(w) for w in X_test])


# ============================================================
# STEP 5 — RESHAPE FOR LSTM
# ============================================================
X_train = X_train[..., None]
X_val   = X_val[..., None]
X_test  = X_test[..., None]

print("\nFinal LSTM shapes:")
print("Train:", X_train.shape)
print("Val:  ", X_val.shape)
print("Test: ", X_test.shape)
print("\ny-rank shapes:", y_train.shape, y_val.shape, y_test.shape)
# Out:
# X: (2179812, 60)
# y: (2179812,)
# stock_ids: (2179812,)
# dates: 2179812
#
# Ranked y distribution:
# count    2.179812e+06
# mean     5.014651e-01
# std      2.886724e-01
# min      2.849003e-03
# 25%      2.507122e-01
# 50%      5.014245e-01
# 75%      7.521368e-01
# max      1.000000e+00
# dtype: float64
#
# Train: (1680691, 60)
# Val:   (353106, 60)
# Test:  (146015, 60)
#
# Final LSTM shapes:
# Train: (1680691, 60, 1)
# Val:   (353106, 60, 1)
# Test:  (146015, 60, 1)
#
# y-rank shapes: (1680691,) (353106,) (146015,)

# %%
df_tmp
# Out:
#               date         y      rank
# 0       2000-03-29 -0.043772  0.327645
# 1       2000-03-30 -0.017926  0.378840
# 2       2000-03-31 -0.020377  0.378840
# 3       2000-04-03 -0.021753  0.382253
# 4       2000-04-04 -0.062671  0.310580
# ...            ...       ...       ...
# 2179807 2025-08-22 -0.077694  0.304843
# 2179808 2025-08-25 -0.109077  0.253561
# 2179809 2025-08-26 -0.090209  0.304843
# 2179810 2025-08-27 -0.104602  0.273504
# 2179811 2025-08-28 -0.093603  0.260000
#
# [2179812 rows x 3 columns]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ======================================================
# 1. MODEL: Rank Regression (predict continuous 0–1 rank)
# ======================================================

model = Sequential([
    LSTM(64, return_sequences=False, input_shape=(WINDOW, 1)),
    Dropout(0.30),

    Dense(32, activation='relu'),
    Dropout(0.20),

    Dense(1, activation='sigmoid')   # --> predicts rank (0..1)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='mse',          # rank regression loss
    metrics=['mae']
)

model.summary()


# ======================================================
# 2. CALLBACKS
# ======================================================

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=4,
    restore_best_weights=True
)

lr_schedule = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-5
)


# ======================================================
# 3. TRAIN MODEL
# ======================================================

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=2048,
    callbacks=[early_stop, lr_schedule],
    verbose=1
)


# ======================================================
# 4. EVALUATE MODEL
# ======================================================

test_loss, test_mae = model.evaluate(X_test, y_test, verbose=1)

print("\n===== TEST METRICS =====")
print(f"Test MSE: {test_loss:.6f}")
print(f"Test MAE: {test_mae:.6f}")


# ======================================================
# 5. PREDICT RANKS
# ======================================================

rank_pred_test = model.predict(
    X_test,
    batch_size=4096,
    verbose=1
).reshape(-1)

print("Predictions shape:", rank_pred_test.shape)
print("\nSample predicted ranks:", rank_pred_test[:20])
# Out:
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_7 (LSTM)                        │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 19,009 (74.25 KB)
#  Trainable params: 19,009 (74.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 75s 91ms/step - loss: 0.0833 - mae: 0.2499 - val_loss: 0.0833 - val_mae: 0.2499 - learning_rate: 0.0010
# Epoch 2/30
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 103s 126ms/step - loss: 0.0833 - mae: 0.2499 - val_loss: 0.0833 - val_mae: 0.2500 - learning_rate: 0.0010
# Epoch 3/30
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 117s 143ms/step - loss: 0.0833 - mae: 0.2499 - val_loss: 0.0833 - val_mae: 0.2499 - learning_rate: 0.0010
# Epoch 4/30
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 112s 136ms/step - loss: 0.0833 - mae: 0.2499 - val_loss: 0.0833 - val_mae: 0.2499 - learning_rate: 5.0000e-04
# Epoch 5/30
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 107s 130ms/step - loss: 0.0833 - mae: 0.2499 - val_loss: 0.0833 - val_mae: 0.2500 - learning_rate: 5.0000e-04
# Epoch 6/30
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 109s 132ms/step - loss: 0.0833 - mae: 0.2498 - val_loss: 0.0833 - val_mae: 0.2499 - learning_rate: 2.5000e-04
# Epoch 7/30
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 112s 137ms/step - loss: 0.0833 - mae: 0.2498 - val_loss: 0.0833 - val_mae: 0.2499 - learning_rate: 2.5000e-04
# Epoch 8/30
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 117s 143ms/step - loss: 0.0833 - mae: 0.2498 - val_loss: 0.0833 - val_mae: 0.2499 - learning_rate: 1.2500e-04
# Epoch 9/30
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 112s 137ms/step - loss: 0.0832 - mae: 0.2498 - val_loss: 0.0833 - val_mae: 0.2499 - learning_rate: 1.2500e-04
# Epoch 10/30
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 123s 150ms/step - loss: 0.0832 - mae: 0.2498 - val_loss: 0.0833 - val_mae: 0.2499 - learning_rate: 6.2500e-05
# 4563/4563 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - loss: 0.0833 - mae: 0.2499
#
# ===== TEST METRICS =====
# Test MSE: 0.083271
# Test MAE: 0.249881
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step
# Predictions shape: (146015,)
#
# Sample predicted ranks: [0.4909232  0.49094865 0.4926444  0.4934804  0.4938409  0.49405634
#  0.4942085  0.49499682 0.49522737 0.49619094 0.49725014 0.4991854
#  0.50016093 0.499775   0.4995141  0.50453496 0.50195163 0.50057685
#  0.5002121  0.5009778 ]

# %% [markdown]
# # Now the backtesting starts

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt


# ============================================================
# CONFIG
# ============================================================
H = HORIZON                    # e.g., 60 trading days
BACKTEST_START = "2024-01-1" # custom start date

THREAD_SHARPE = {}
THREAD_RETURN = {}
THREAD_MAXDD = {}
THREAD_FINAL = {}


# ============================================================
# METRIC FUNCTIONS
# ============================================================

def sharpe_ratio(r):
    r = np.array(r)
    if len(r) < 2:
        return np.nan
    return r.mean() / (r.std() + 1e-12)

def max_drawdown(cum_curve):
    peak = np.maximum.accumulate(cum_curve)
    dd = (cum_curve - peak) / peak
    return dd.min()

def volatility(r):
    return np.std(r)

def max_losing_streak(r):
    streak = 0
    max_streak = 0
    for ret in r:
        if ret < 0:
            streak += 1
            max_streak = max(max_streak, streak)
        else:
            streak = 0
    return max_streak


# ============================================================
# SPY DATA
# ============================================================

spy = yf.download("SPY", start="1990-01-01", progress=False, auto_adjust=True)

if isinstance(spy.columns, pd.MultiIndex):
    spy_close = spy["Close"].iloc[:, 0]
else:
    spy_close = spy["Close"]

spy = pd.DataFrame({"Close": spy_close})
spy["forward"] = spy["Close"].shift(-H)
spy["ret"] = (spy["forward"] - spy["Close"]) / spy["Close"]


# ============================================================
# BACKTEST FUNCTION
# ============================================================

def run_backtest(TOP_K):

    df = pd.DataFrame({
        "date": dates_test,
        "stock_id": ids_test,
        "y_pred": rank_pred_test,
        "true_return": y[test_mask]
    })

    df = df.dropna().reset_index(drop=True)
    df["date"] = pd.to_datetime(df["date"])
    df["ticker"] = np.array(tickers)[df["stock_id"].values]

    df = df[df["date"] >= pd.Timestamp(BACKTEST_START)].reset_index(drop=True)
    test_dates = np.sort(df["date"].unique())

    portfolio_dates = []
    portfolio_returns = []
    portfolio_n = []
    spy_returns = []

    i = 0
    while True:
        if i >= len(test_dates):
            break

        t0 = test_dates[i]
        idx0 = np.where(test_dates == t0)[0][0]
        idx1 = idx0 + H

        if idx1 >= len(test_dates):
            break

        t1 = test_dates[idx1]

        df_t = df[df["date"] == t0].sort_values("y_pred", ascending=False).head(TOP_K)

        realized = df_t["true_return"].mean()
        nstocks  = df_t.shape[0]

        portfolio_dates.append(t1)
        portfolio_returns.append(realized)
        portfolio_n.append(nstocks)

        # SPY benchmark aligned
        if t0 in spy.index:
            spy_idx0 = spy.index.get_loc(t0)
            spy_idx1 = spy_idx0 + H
            if spy_idx1 < len(spy):
                spy_returns.append(float(spy["ret"].iloc[spy_idx1]))
            else:
                spy_returns.append(np.nan)
        else:
            spy_returns.append(np.nan)

        i += H

    df_port = pd.DataFrame({
        "date": portfolio_dates,
        "model_return": portfolio_returns,
        "spy_return": spy_returns,
        "nstocks": portfolio_n
    }).dropna().reset_index(drop=True)

    df_port["cum_model"] = (1 + df_port["model_return"]).cumprod()
    df_port["cum_spy"]   = (1 + df_port["spy_return"]).cumprod()

    return df_port


# ============================================================
# FULL BACKTEST FOR TOP_K = 5, 15, 25
# ============================================================

results = {}
metrics_table = []

for TOP_K in [12, 20, 30]:
    print(f"\n===== RUNNING BACKTEST FOR TOP {TOP_K} =====")
    df_port = run_backtest(TOP_K)
    results[TOP_K] = df_port

    model_r = df_port["model_return"].to_numpy()
    spy_r   = df_port["spy_return"].to_numpy()

    metrics_table.append({
        "top_k": TOP_K,
        "model_mean_return": np.mean(model_r),
        "model_std_return":  np.std(model_r),
        "model_sharpe":      sharpe_ratio(model_r),
        "model_max_drawdown": max_drawdown(df_port["cum_model"].to_numpy()),
        "model_final_cum": df_port["cum_model"].iloc[-1],

        "spy_mean_return": np.mean(spy_r),
        "spy_std_return":  np.std(spy_r),
        "spy_sharpe":      sharpe_ratio(spy_r),
        "spy_max_drawdown": max_drawdown(df_port["cum_spy"].to_numpy()),
        "spy_final_cum":    df_port["cum_spy"].iloc[-1],
    })

metrics_df = pd.DataFrame(metrics_table)


# ============================================================
# BUILD DAILY DF FOR THREAD ANALYSIS
# ============================================================

df_daily = pd.DataFrame({
    "date": dates_test,
    "stock_id": ids_test,
    "y_pred": rank_pred_test,
    "true_return": y[test_mask]
}).dropna().reset_index(drop=True)

df_daily["date"] = pd.to_datetime(df_daily["date"])
df_daily["ticker"] = np.array(tickers)[df_daily["stock_id"].values]
df_daily = df_daily.sort_values(["date", "y_pred"], ascending=[True, False])
unique_test_dates = np.sort(df_daily["date"].unique())


# ============================================================
# THREAD ANALYSIS (60 OFFSETS)
# ============================================================

for TOP_K in [12, 20, 30]:

    returns_list = []
    sharpe_list = []
    maxdd_list = []
    final_list = []

    for offset in range(H):

        quarterly_returns = []
        i = offset

        while i < len(unique_test_dates):
            t0 = unique_test_dates[i]
            idx1 = i + H
            if idx1 >= len(unique_test_dates):
                break

            df_t = df_daily[df_daily["date"] == t0]\
                        .sort_values("y_pred", ascending=False)\
                        .head(TOP_K)

            quarterly_returns.append(float(df_t["true_return"].mean()))
            i += H

        q = np.array(quarterly_returns)

        returns_list.append(q.mean())
        sharpe_list.append(sharpe_ratio(q))

        cum_curve = (1 + q).cumprod()
        maxdd_list.append(max_drawdown(cum_curve))
        final_list.append(cum_curve[-1])

    THREAD_RETURN[TOP_K] = np.array(returns_list)
    THREAD_SHARPE[TOP_K] = np.array(sharpe_list)
    THREAD_MAXDD[TOP_K] = np.array(maxdd_list)
    THREAD_FINAL[TOP_K] = np.array(final_list)

    metrics_df.loc[metrics_df.top_k == TOP_K, "thread_return_mean"] = THREAD_RETURN[TOP_K].mean()
    metrics_df.loc[metrics_df.top_k == TOP_K, "thread_return_std"]  = THREAD_RETURN[TOP_K].std()

    metrics_df.loc[metrics_df.top_k == TOP_K, "thread_sharpe_mean"] = THREAD_SHARPE[TOP_K].mean()
    metrics_df.loc[metrics_df.top_k == TOP_K, "thread_sharpe_std"]  = THREAD_SHARPE[TOP_K].std()

    metrics_df.loc[metrics_df.top_k == TOP_K, "thread_maxdd_worst"] = THREAD_MAXDD[TOP_K].min()
    metrics_df.loc[metrics_df.top_k == TOP_K, "thread_finalcum_mean"] = THREAD_FINAL[TOP_K].mean()


# ============================================================
# PRINT FINAL METRICS TABLE
# ============================================================

print("\n==============================")
print(" FINAL METRICS COMPARISON TABLE")
print("==============================\n")
print(metrics_df)


# ============================================================
# CUMULATIVE NET VALUE PLOT (MODEL VS SPY)
# ============================================================

for TOP_K in [12, 20, 30]:
    df_port = results[TOP_K]

    plt.figure(figsize=(15,7))
    plt.plot(df_port["date"], df_port["cum_model"],
             label=f"Model TOP {TOP_K}", linewidth=2)
    plt.plot(df_port["date"], df_port["cum_spy"],
             label="SPY (60-day forward)", linewidth=2, alpha=0.7)

    plt.title(f"Quarterly-Aligned Backtest — Model vs SPY (TOP {TOP_K})", fontsize=16)
    plt.grid(True)
    plt.legend()
    plt.show()



# ============================================================
# SAVE METRICS
# ============================================================

metrics_df.to_csv("model_comparison_v01.csv", index=False)
metrics_df.to_json("model_comparison_v01.json", orient="records")
# Out:
# ===== RUNNING BACKTEST FOR TOP 12 =====
#
# ===== RUNNING BACKTEST FOR TOP 20 =====
#
# ===== RUNNING BACKTEST FOR TOP 30 =====
#
# ==============================
#  FINAL METRICS COMPARISON TABLE
# ==============================
#
#    top_k  model_mean_return  model_std_return  model_sharpe  \
# 0     12           0.000493          0.058550      0.008418
# 1     20           0.016064          0.050575      0.317615
# 2     30           0.050678          0.069588      0.728260
#
#    model_max_drawdown  model_final_cum  spy_mean_return  spy_std_return  \
# 0           -0.143663         0.992852         0.040032        0.048628
# 1           -0.068869         1.092256         0.040032        0.048628
# 2           -0.028211         1.327997         0.040032        0.048628
#
#    spy_sharpe  spy_max_drawdown  spy_final_cum  thread_return_mean  \
# 0    0.823215         -0.065384        1.25684            0.032803
# 1    0.823215         -0.065384        1.25684            0.036064
# 2    0.823215         -0.065384        1.25684            0.040110
#
#    thread_return_std  thread_sharpe_mean  thread_sharpe_std  \
# 0           0.024106            0.583019           0.512938
# 1           0.020197            0.652665           0.451428
# 2           0.016867            0.765008           0.455985
#
#    thread_maxdd_worst  thread_finalcum_mean
# 0           -0.150273              1.208246
# 1           -0.128346              1.226184
# 2           -0.105350              1.254470

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ======================================================
# MODEL BUILDER
# ======================================================
def build_model():
    model = Sequential([
        LSTM(64, input_shape=(WINDOW,1)),
        Dropout(0.30),
        Dense(32, activation='relu'),
        Dropout(0.20),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# ======================================================
# CONFIG
# ======================================================
H = HORIZON
TOP_K = 12

cutoffs = [
    "2024-01-01",   # <-- added starting quarter
    "2024-03-30",
    "2024-06-30",
    "2024-09-30",
    "2024-12-30"
]

# store everything here
rolling_results = []   # one row per cutoff


# ======================================================
# METRIC HELPERS
# ======================================================
def sharpe_ratio(r):
    r = np.array(r)
    if len(r) < 2:
        return np.nan
    return r.mean() / (r.std() + 1e-12)

def max_drawdown(cum_curve):
    peak = np.maximum.accumulate(cum_curve)
    dd = (cum_curve - peak) / peak
    return dd.min()

def volatility(r):
    return np.std(r)

def max_losing_streak(r):
    streak = 0
    max_streak = 0
    for ret in r:
        if ret < 0:
            streak += 1
            max_streak = max(max_streak, streak)
        else:
            streak = 0
    return max_streak


# ======================================================
# MAIN ROLLING LOOP
# ======================================================
for cutoff in cutoffs:
    cutoff_date = pd.Timestamp(cutoff)

    # 1. TRAIN/TEST SPLIT
    train_mask = dates_pd < cutoff_date
    test_mask_single = dates_pd == cutoff_date + pd.Timedelta(days=1)

    # fallback: next available trading day
    if test_mask_single.sum() == 0:
        nearest = dates_pd[dates_pd > cutoff_date].min()
        test_mask_single = dates_pd == nearest
        test_date = nearest
    else:
        test_date = cutoff_date + pd.Timedelta(days=1)

    # 2. TRAIN MODEL
    model = build_model()
    early_stop = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
    lr_sched = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-5)

    model.fit(
        X[train_mask], y_rank[train_mask],
        validation_split=0.1,
        epochs=30,
        batch_size=2048,
        callbacks=[early_stop, lr_sched],
        verbose=1
    )

    # 3. PREDICT FOR TEST DATE
    pred = model.predict(X[test_mask_single]).reshape(-1)
    ids_pred = stock_ids[test_mask_single]
    dates_pred = dates_pd[test_mask_single]

    df_pred = pd.DataFrame({
        "date": dates_pred,
        "id": ids_pred,
        "rank": pred,
        "true_return": y[test_mask_single]
    }).sort_values("rank", ascending=False).head(TOP_K)

    realized_return = df_pred["true_return"].mean()

    # 4. SPY
    d0 = test_date
    if d0 in spy.index:
        idx0 = spy.index.get_loc(d0)
        idx1 = idx0 + H
        if idx1 < len(spy):
            spy_ret = float(spy["ret"].iloc[idx1])
        else:
            spy_ret = np.nan
    else:
        spy_ret = np.nan

    # store row
    rolling_results.append({
        "cutoff": cutoff,
        "date_pred": str(test_date.date()),
        "model_return": realized_return,
        "spy_return": spy_ret
    })


# ======================================================
# BUILD ROLLING RESULT TABLE
# ======================================================
df_roll = pd.DataFrame(rolling_results)

# cumulative curves
df_roll["cum_model"] = (1 + df_roll["model_return"]).cumprod()
df_roll["cum_spy"]   = (1 + df_roll["spy_return"]).cumprod()

# rolling metrics across the 5 quarters
r_model = df_roll["model_return"].to_numpy()
r_spy   = df_roll["spy_return"].to_numpy()

rolling_metrics = {
    "model_sharpe": sharpe_ratio(r_model),
    "model_total_return": df_roll["cum_model"].iloc[-1],
    "model_maxdrawdown": max_drawdown(df_roll["cum_model"].to_numpy()),
    "model_volatility": volatility(r_model),
    "model_losing_streak": max_losing_streak(r_model),

    "spy_sharpe": sharpe_ratio(r_spy),
    "spy_total_return": df_roll["cum_spy"].iloc[-1],
    "spy_maxdrawdown": max_drawdown(df_roll["cum_spy"].to_numpy()),
    "spy_volatility": volatility(r_spy),
    "spy_losing_streak": max_losing_streak(r_spy)
}


# ======================================================
# PRINT TABLE + METRICS
# ======================================================
print("\n===== ROLLING LIVE TEST TABLE =====\n")
print(df_roll)

print("\n===== ROLLING LIVE METRICS (5 QUARTERS) =====")
for k,v in rolling_metrics.items():
    print(f"{k}: {v:.6f}")


# ======================================================
# OPTIONAL: PLOT CUMULATIVE CURVES
# ======================================================

plt.figure(figsize=(15,6))
plt.plot(df_roll["date_pred"], df_roll["cum_model"], marker="o", label="Model")
plt.plot(df_roll["date_pred"], df_roll["cum_spy"], marker="o", label="SPY")
plt.grid(True)
plt.title("Rolling Quarterly Live Test — Model vs SPY")
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\benna435\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 894/894 ━━━━━━━━━━━━━━━━━━━━ 72s 80ms/step - loss: 0.0830 - mae: 0.2493 - val_loss: 0.0835 - val_mae: 0.2501 - learning_rate: 0.0010
# Epoch 2/30
# 894/894 ━━━━━━━━━━━━━━━━━━━━ 92s 103ms/step - loss: 0.0827 - mae: 0.2489 - val_loss: 0.0835 - val_mae: 0.2501 - learning_rate: 0.0010
# Epoch 3/30
# 894/894 ━━━━━━━━━━━━━━━━━━━━ 108s 121ms/step - loss: 0.0827 - mae: 0.2489 - val_loss: 0.0834 - val_mae: 0.2500 - learning_rate: 0.0010
# Epoch 4/30
# 894/894 ━━━━━━━━━━━━━━━━━━━━ 115s 128ms/step - loss: 0.0827 - mae: 0.2489 - val_loss: 0.0834 - val_mae: 0.2500 - learning_rate: 5.0000e-04
# Epoch 5/30
# 894/894 ━━━━━━━━━━━━━━━━━━━━ 112s 125ms/step - loss: 0.0827 - mae: 0.2489 - val_loss: 0.0834 - val_mae: 0.2500 - learning_rate: 5.0000e-04
# Epoch 6/30
# 894/894 ━━━━━━━━━━━━━━━━━━━━ 114s 128ms/step - loss: 0.0827 - mae: 0.2489 - val_loss: 0.0834 - val_mae: 0.2500 - learning_rate: 2.5000e-04
# Epoch 7/30
# 622/894 ━━━━━━━━━━━━━━━━━━━━ 32s 121ms/step - loss: 0.0826 - mae: 0.2487

# %%
# ===== PRINT TOP 5 PREDICTED STOCKS PER REBALANCE =====

print("===== TOP 5 PREDICTIONS PER REBALANCE =====")

# ensure ticker exists
if "ticker" not in df.columns:
    df["ticker"] = np.array(tickers)[df["stock_id"].values]

i = 0
while i < len(test_dates):

    t0 = test_dates[i]
    t1 = t0 + pd.Timedelta(days=HORIZON)

    if t1 > test_dates[-1]:
        break

    df_t = df[df["date"] == t0].sort_values("y_pred", ascending=False).head(TOP_K)

    # safety check
    if "ticker" not in df_t.columns:
        raise RuntimeError("ticker column missing in df_t")

    tickers_top5 = df_t["ticker"].tolist()

    print(f"\nRebalance date: {pd.Timestamp(t0).date()}")
    print("Top 5 predicted stocks:", tickers_top5)

    i += HORIZON
# Out:
# ===== TOP 5 PREDICTIONS PER REBALANCE =====
#
# Rebalance date: 2024-01-16
# Top 5 predicted stocks: ['HAL', 'APA', 'XOM', 'HUM', 'SLB', 'EOG', 'OXY', 'SBUX', 'BDX', 'BKR', 'COP', 'BMY', 'PEG', 'PFE', 'CVX', 'CME', 'PNW', 'GIS', 'WMB', 'DIS', 'HRL', 'DVN', 'CPRT', 'HAS', 'CSCO']
#
# Rebalance date: 2024-04-11
# Top 5 predicted stocks: ['KIM', 'MDLZ', 'LH', 'SJM', 'UNH', 'AAPL', 'TDY', 'AMGN', 'ADBE', 'HUM', 'SBUX', 'VFC', 'GILD', 'EXPE', 'INTC', 'EXPD', 'MTCH', 'MSCI', 'TFX', 'JBHT', 'CMCSA', 'XRAY', 'ILMN', 'IPGP', 'GPN']
#
# Rebalance date: 2024-07-09
# Top 5 predicted stocks: ['AIZ', 'AAP', 'CRL', 'GPC', 'CI', 'DE', 'LVS', 'MCD', 'SYY', 'DIS', 'IEX', 'ITW', 'EL', 'MLM', 'WYNN', 'GIS', 'VMC', 'NSC', 'XRAY', 'BMY', 'CMI', 'MAS', 'DHI', 'HST', 'SWK']
#
# Rebalance date: 2024-10-02
# Top 5 predicted stocks: ['HUM', 'MCK', 'SWKS', 'DVN', 'AAP', 'DXCM', 'CRL', 'OXY', 'DLTR', 'MRK', 'HAL', 'BEN', 'EW', 'APA', 'F', 'SNPS', 'ZION', 'DG', 'ADM', 'QCOM', 'LKQ', 'MCHP', 'BAC', 'TXT', 'SLB']
#
# Rebalance date: 2024-12-27
# Top 5 predicted stocks: ['MDLZ', 'FCX', 'STX', 'IFF', 'NEM', 'BAX', 'AOS', 'CPB', 'SWK', 'STE', 'SBAC', 'MHK', 'LMT', 'DHI', 'ADM', 'UHS', 'NOC', 'AMD', 'AMGN', 'GIS', 'TFX', 'AMT', 'MCHP', 'LIN', 'ELV']
#
# Rebalance date: 2025-03-27
# Top 5 predicted stocks: ['UAA', 'CLX', 'LEN', 'LUMN', 'IFF', 'HOLX', 'PVH', 'HST', 'EL', 'VTRS', 'OMC', 'CF', 'UPS', 'ILMN', 'TER', 'PKG', 'LVS', 'IEX', 'AVY', 'PPG', 'NWL', 'WAT', 'WHR', 'ZBRA', 'SWKS']
#
# Rebalance date: 2025-06-24
# Top 5 predicted stocks: ['TAP', 'CPB', 'CAG', 'CLX', 'TFX', 'ELV', 'TMUS', 'GIS', 'ED', 'TSN', 'ZBH', 'VTR', 'CMS', 'TMO', 'BDX', 'BRK-B', 'UNH', 'DVA', 'YUM', 'EXC', 'PNW', 'FISV', 'CL', 'BMY', 'CNC']
